# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#from darnn_network import encoder, decoder, da_rnn, encoder_dropout, decoder_dropout, da_rnn_dropout
from error_metrics import *
from moving_window_tests import *

# %%
# %matplotlib inline
np.set_printoptions(suppress=True)
pd.set_option('display.max_rows',1000)
pd.set_option('display.max_columns',1000)

# %%
data = pd.read_csv('nasdaq100_padding.csv')

# %%
data["NDX"].plot()
plt.show()

# %%
n_timeseries = data.shape[1] - 1
train_length = 35100
val_length = 2730
test_length = 2730
target = 'NDX'
prediction_horizon = 1
y_true = data[target].shift(-prediction_horizon).fillna(method="ffill").values # lag1
pred_current = data[target].values

# %%
evaluate(y_true[-2730:], pred_current[-2730:])
# Out:
# {'rmse': 1.4140642893043285,
#  'mae': 0.8939901098901092,
#  'mape': 0.018100552748340798,
#  'mda': 0.5338951997068523,
#  'mda2': 0.0007328691828508611}

# %% [markdown]
# # Rolling OLS specified Train/Valid/Test sets
#
# - Split window into two: train and test with given moving window size
# - We will set window size as 300 which is 180 minute = 3 hours
# - Rolling for
# - Test length is usually one for rolling

# %%
ols_pred, ols_true, trains, tests, lookback = AR_moving_fit(data, order=1, lookback=500, 
                                                            test_window=1, test_length=2730,
                                                           target='NDX')
evaluate(ols_pred,ols_true)
# Out:
# 100.00 %

# %%
var_pred, var_true, trains, tests, lookback = VAR_fit(data, lookback=500, 
                                                            test_window=1, test_length=2730,
                                                           target='NDX')
evaluate(var_pred,var_true)
# Out:
# 0.51 %
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\Users\User\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:215: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...

# %%
evaluate(ols_pred,ols_true)
# Out:
# {'rmse': 1.5159091590146707,
#  'mae': 1.012368035196467,
#  'mape': 0.020494584558929125,
#  'mda': 0.5360938072554049,
#  'mda2': 0.7680469036277024}

# %%
evaluate(ols_pred,ols_true)
# Out:
# {'rmse': 1.5159091590146707,
#  'mae': 1.012368035196467,
#  'mape': 0.020494584558929125,
#  'mda': 0.5360938072554049,
#  'mda2': 0.7680469036277024}

# %%
ols_pred, ols_true, trains, tests, look_back = AR_moving_fit(data, order=1, look_back=1000, test_window=1 )
# Out:
# 100.00 %

# %%
print(len(ols_pred), len(ols_true))
evaluate(ols_pred,ols_true)
# Out:
# 2730 2730
# {'rmse': 1.428022607294923,
#  'mae': 0.9193438290038682,
#  'mape': 0.018612202696862035,
#  'mda': 0.543788933675339,
#  'mda2': 0.7658482960791498}

# %%
# Frank code with lookback 37828
ols_pred, ols_true, trains, tests, look_back = AR_moving_fit(data, order=1, look_back=37828, test_window=1 )
# Out:
# 100.00 %

# %%
evaluate(ols_pred,ols_true)
# Out:
# {'rmse': 1.3844101510334201,
#  'mae': 0.8636746490037681,
#  'mape': 0.017487133851000813,
#  'mda': 0.546353975815317,
#  'mda2': 0.7801392451447416}

# %%
ols_pred, ols_true, trains, tests, look_back = AR_moving_fit(data, order=1, look_back=2000, test_window=1 )
evaluate(ols_pred,ols_true)
# Out:
# 100.00 %
# {'rmse': 1.340022157356488,
#  'mae': 0.8777727202980521,
#  'mape': 0.017770661360554708,
#  'mda': 0.5423231953096372,
#  'mda2': 0.7566874312935141}
